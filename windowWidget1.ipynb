# %%
from tkinter import*

window = Tk()

## 화면 구성하고 처리하는 부분 ##
photo = PhotoImage(file ="gif/dog.gif")
label1 = Label(window, image = photo)

label1.pack()

window.mainloop()

# %%
from tkinter import*

window = Tk()

## 화면 구성하고 처리하는 부분 ##
photo = PhotoImage(file ="gif/cat.gif")
label1 = Label(window, image = photo)

label1.pack()

photo2 = PhotoImage(file ="gif/cat2.gif")
label2 = Label(window, image = photo)

label2.pack(side=LEFT)


window.mainloop()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# Input In [3], in <cell line: 7>()
#       5 ## 화면 구성하고 처리하는 부분 ##
#       6 photo = PhotoImage(file ="gif/cat.gif")
# ----> 7 label1 = Label(window, image = photo)
#       9 label1.pack()
#      11 photo2 = PhotoImage(file ="gif/cat2.gif")
#
# File C:\ProgramData\Anaconda3\lib\tkinter\__init__.py:3148, in Label.__init__(self, master, cnf, **kw)
#    3130 def __init__(self, master=None, cnf={}, **kw):
#    3131     """Construct a label widget with the parent MASTER.
#    3132
#    3133     STANDARD OPTIONS
#    (...)
#    3146
#    3147     """
# -> 3148     Widget.__init__(self, master, 'label', cnf, kw)
#
# File C:\ProgramData\Anaconda3\lib\tkinter\__init__.py:2572, in BaseWidget.__init__(self, master, widgetName, cnf, kw, extra)
#    2570 for k, v in classes:
#    2571     del cnf[k]
# -> 2572 self.tk.call(
#    2573     (widgetName, self._w) + extra + self._options(cnf))
#    2574 for k, v in classes:
#    2575     k.configure(self, v)
#
# TclError: image "pyimage2" doesn't exist
